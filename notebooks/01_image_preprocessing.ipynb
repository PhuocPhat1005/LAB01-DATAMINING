# %% [markdown]
# <div style="text-align: center;">
#     <i><b>ĐẠI HỌC QUỐC GIA THÀNH PHỐ HỒ CHÍ MINH</b></i>
#     <br>
#     <i><b>TRƯỜNG ĐẠI HỌC KHOA HỌC TỰ NHIÊN</b></i>
#     <br>
#     <i><b>KHOA CÔNG NGHỆ THÔNG TIN CHẤT LƯỢNG CAO</b></i>
#     <br>
#     <b>------------o------------</b>
#     <br>
#     <b>KHAI THÁC DỮ LIỆU VÀ ỨNG DỤNG - CSC14004</b>
# </div>
#
# <h1 style="text-align: center; color: red;"><b>LAB 01: TIỀN XỬ LÝ DỮ LIỆU HÌNH ẢNH</b></h1>
#
# <div style = "text-align: center;"> <ins><b>Ngày cập nhật cuối cùng:</b></ins> 01 / 11 / 2025</div>
#
# ---
